# %%
import numpy as np
from scipy.signal import butter, freqz
import matplotlib.pyplot as plt

# Filter parameters
fs = 1000  # Sampling frequency
cutoff = 100  # Cutoff frequency
order = 4  # Filter order

# Designing Butterworth filter and getting coefficients
coefficients = butter(order, cutoff / (fs / 2), btype='low')  # Filter coefficients

# Computing frequency response
freq_response = freqz(*coefficients, worN=8000)

# Plotting the results
plt.plot(freq_response[0] * fs / (2 * np.pi), 20 * np.log10(np.abs(freq_response[1])))
plt.title('Frekventni odziv lowpass Butterworth filtera')
plt.xlabel('Frekvencija [Hz]')
plt.ylabel('Amplituda [dB]')
plt.grid()
plt.ylim([-80, 5])
plt.xlim([0, fs / 2])
plt.show()

# %%
from getpass import getpass
import os

# Unesite URL vašeg GitHub repozitorijuma
repo_url = "https://github.com/AmrSa2002/Optimizacione-tehnike-u-digitalnim-filterima.git"  # zamenite sa vašim URL-om

# Unesite GitHub token
token = getpass("Unesite vaš GitHub token: ")

# Pripremite autentifikovani URL
auth_repo_url = repo_url.replace("https://", f"https://{token}@")

# Klonirajte repozitorijum
os.system(f"git clone {auth_repo_url}")

# Prikaz kloniranih fajlova
os.system("ls")
# Out:
# Unesite vaš GitHub token: ··········
# 0

# %%
from getpass import getpass
import os

repo_url = "https://github.com/AmrSa2002/Optimizacione-tehnike-u-digitalnim-filterima.git"  # Zamenite sa vašim
token = getpass("Unesite vaš GitHub token: ")

# Kreiranje autentifikovanog URL-a
auth_repo_url = repo_url.replace("https://", f"https://{token}@")

# Kloniranje repozitorijuma
os.system(f"git clone {auth_repo_url}")
# Out:
# Unesite vaš GitHub token: ··········
# 32768

# %%
# !ls
# Out:
# Optimizacione-tehnike-u-digitalnim-filterima  sample_data

# %%
with open('/content/filters/iir_butterworth_lowpass.py', 'w') as f:
    f.write("# vaš kod ovde")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-66a99866d894> in <cell line: 1>()
# ----> 1 with open('/content/filters/iir_butterworth_lowpass.py', 'w') as f:
#       2     f.write("# vaš kod ovde")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/filters/iir_butterworth_lowpass.py'
